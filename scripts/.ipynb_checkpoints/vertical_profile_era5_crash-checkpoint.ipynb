# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np
import numpy.ma as ma
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from netCDF4 import Dataset
import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point
import xarray as xr
import glob
from datetime import datetime, timedelta
from numba import jit
# Out:
# /tmp/ipykernel_1057/1096757959.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# define paths
era5crash_basefilepath = '/skydata2/dylanelliott/letkf-hybrid-speedy/DATA/uniform_letkf_anal/era5_crash_ens_members_test/'
speedy_basefilepath = '/skydata2/dylanelliott/letkf-hybrid-speedy/DATA/uniform_letkf_anal/speedy_cov_1_3_40MEM_individual_ens_member_20110101_20110601/'

era5crash_anal_mean = era5crash_basefilepath + 'mean_output/out.nc'
speedy_anal_mean = speedy_basefilepath + 'mean_output/out.nc'

# define time slice
start_year = 2011
end_year = 2011

startdate = datetime(2011,1,1,0)
enddate = datetime(2011,1,1,18)
time_slice = slice(startdate,enddate)

# define variables and define level

level = 0.2 #0.2#0.95#0.51
level_era = 2 #2#7 #4

var_era = 'Temperature'#'Specific_Humidity'#'Temperature' #'V-wind'
var_da =  't'#'q'#'t'#'v'
print('you selected for variable =',var_era)
print('at level =',level)
timestep_6hrly = 6

year = start_year
ERA5_reanalysis_ds = f'/skydata2/troyarcomano/ERA_5/{year}/era_5_y{year}_regridded_mpi_fixed_var.nc'

# Read in datasets
ds_ERA5 = xr.open_dataset(ERA5_reanalysis_ds)
ds_


## TROY Vertical Profile script
# /skydata2/troyarcomano/arcomano_2022_paper

# Average Vertical profile needs:
# average for each level, so take an average at each level
# then average those across time

# x-axis = value of variable selected say specific humidity
# y-axis = sigma level
# Out:
# you selected for variable = Temperature
# at level = 0.2
# <xarray.Dataset>
# Dimensions:            (Lon: 96, Lat: 48, Timestep: 8760, Sigma_Level: 8)
# Coordinates:
#   * Lon                (Lon) float32 0.0 3.75 7.5 11.25 ... 348.8 352.5 356.2
#   * Lat                (Lat) float32 -87.16 -83.48 -79.78 ... 79.78 83.48 87.16
# Dimensions without coordinates: Timestep, Sigma_Level
# Data variables:
#     Temperature        (Timestep, Sigma_Level, Lat, Lon) float32 ...
#     U-wind             (Timestep, Sigma_Level, Lat, Lon) float32 ...
#     V-wind             (Timestep, Sigma_Level, Lat, Lon) float32 ...
#     Specific_Humidity  (Timestep, Sigma_Level, Lat, Lon) float32 ...
#     logp               (Timestep, Lat, Lon) float32 ...
